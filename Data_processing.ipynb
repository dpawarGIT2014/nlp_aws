# %%
YOUR_NAME = 'nlp_aws'

# %%
import sagemaker
from sagemaker import get_execution_role
import json
import boto3
import pandas as pd

sess = sagemaker.Session()

role = get_execution_role()
print(role) # This is the role that SageMaker would use to leverage AWS resources (S3, CloudWatch) on your behalf

bucket = sess.default_bucket() # Replace with your own bucket name if needed
print(bucket)
prefix = '{}/nlp_aws'.format(YOUR_NAME) #Replace with the prefix under which you want to store the data if needed
# Out:
# arn:aws:iam::023375022819:role/service-role/AmazonSageMaker-ExecutionRole-20190729T110615
# sagemaker-us-east-1-023375022819

# %%
# !wget https://s3.amazonaws.com/fast-ai-nlp/amazon_review_polarity_csv.tgz
# Out:
# --2019-08-27 19:45:00--  https://s3.amazonaws.com/fast-ai-nlp/amazon_review_polarity_csv.tgz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.146.37
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.146.37|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 688339454 (656M) [application/x-tar]
# Saving to: ‘amazon_review_polarity_csv.tgz’
#
# amazon_review_polar 100%[===================>] 656.45M  46.3MB/s    in 13s
#
# 2019-08-27 19:45:13 (51.7 MB/s) - ‘amazon_review_polarity_csv.tgz’ saved [688339454/688339454]

# %%
# !tar -xzvf amazon_review_polarity_csv.tgz
# Out:
# amazon_review_polarity_csv/
# amazon_review_polarity_csv/train.csv
# amazon_review_polarity_csv/readme.txt
# amazon_review_polarity_csv/test.csv

# %%
# !head amazon_review_polarity_csv/train.csv -n 3
# Out:
# "2","Stuning even for the non-gamer","This sound track was beautiful! It paints the senery in your mind so well I would recomend it even to people who hate vid. game music! I have played the game Chrono Cross but out of all of the games I have ever played it has the best music! It backs away from crude keyboarding and takes a fresher step with grate guitars and soulful orchestras. It would impress anyone who cares to listen! ^_^"
# "2","The best soundtrack ever to anything.","I'm reading a lot of reviews saying that this is the best 'game soundtrack' and I figured that I'd write a review to disagree a bit. This in my opinino is Yasunori Mitsuda's ultimate masterpiece. The music is timeless and I'm been listening to it for years now and its beauty simply refuses to fade.The price tag on this is pretty staggering I must say, but if you are going to buy any cd for this much money, this is the only one that I feel would be worth every penny."
# "2","Amazing!","This soundtrack is my favorite music of all time, hands down. The intense sadness of ""Prisoners of Fate"" (which means all the more if you've played the game) and the hope in ""A Distant Promise"" and ""Girl who Stole the Star"" have been an important inspiration to me personally throughout my teen years. The higher energy tracks like ""Chrono Cross ~ Time's Scar~"", ""Time of the Dreamwatch"", and ""Chronomantique"" (indefinably remeniscent of Chrono Trigger) are all absolutely superb as well.This soundtrack is amazing music, probably the best of this composer's work (I haven't heard the Xenogears soundtrack, so I can't say for sure), and even if you've never played the game, it would be worth twice the price to buy it.I wish I could give it 6 stars."

# %%
# !cat amazon_review_polarity_csv/readme.txt
# Out:
# Amazon Review Polaridy Dataset
#
# Version 3, Updated 09/09/2015
#
# ORIGIN
#
# The Amazon reviews dataset consists of reviews from amazon. The data span a period of 18 years, including ~35 million reviews up to March 2013. Reviews include product and user information, ratings, and a plaintext review. For more information, please refer to the following paper: J. McAuley and J. Leskovec. Hidden factors and hidden topics: understanding rating dimensions with review text. RecSys, 2013.
#
# The Amazon reviews polarity dataset is constructed by Xiang Zhang (xiang.zhang@nyu.edu) from the above dataset. It is used as a text classification benchmark in the following paper: Xiang Zhang, Junbo Zhao, Yann LeCun. Character-level Convolutional Networks for Text Classification. Advances in Neural Information Processing Systems 28 (NIPS 2015).
#
#
# DESCRIPTION
#
# The Amazon reviews polarity dataset is constructed by taking review score 1 and 2 as negative, and 4 and 5 as positive. Samples of score 3 is ignored. In the dataset, class 1 is the negative and class 2 is the positive. Each class has 1,800,000 training samples and 200,000 testing samples.
#
# The files train.csv and test.csv contain all the training samples as comma-sparated values. There are 3 columns in them, corresponding to class index (1 or 2), review title and review text. The review title and text are escaped using double quotes ("), and any internal double quote is escaped by 2 double quotes (""). New lines are escaped by a backslash followed with an "n" character, that is "\n".

# %%
sess.upload_data(path='amazon_review_polarity_csv/train.csv', bucket=bucket, key_prefix=prefix)
sess.upload_data(path='amazon_review_polarity_csv/readme.txt', bucket=bucket, key_prefix=prefix)
sess.upload_data(path='amazon_review_polarity_csv/test.csv', bucket=bucket, key_prefix=prefix)
# Out:
# 's3://sagemaker-us-east-1-023375022819/nlp_aws/nlp_aws/test.csv'

# %%
df_train = pd.read_csv("s3://sagemaker-us-east-1-023375022819/NLP_AWS/NLP_AWS/train.csv", names=["Label", "Title", "Review"])

# %%
df_test = pd.read_csv("s3://sagemaker-us-east-1-023375022819/NLP_AWS/NLP_AWS/test.csv", names=["Label", "Title", "Review"])

# %%
df_train
# Out:
#          Label                                              Title  \
# 0            2                     Stuning even for the non-gamer
# 1            2              The best soundtrack ever to anything.
# 2            2                                           Amazing!
# 3            2                               Excellent Soundtrack
# 4            2  Remember, Pull Your Jaw Off The Floor After He...
# 5            2                            an absolute masterpiece
# 6            1                                       Buyer beware
# 7            2                                     Glorious story
# 8            2                                   A FIVE STAR BOOK
# 9            2                      Whispers of the Wicked Saints
# 10           1                                         The Worst!
# 11           2                                         Great book
# 12           2                                         Great Read
# 13           1                                          Oh please
# 14           1                               Awful beyond belief!
# 15           1            Don't try to fool us with fake reviews.
# 16           2                     A romantic zen baseball comedy
# 17           2                 Fashionable Compression Stockings!
# 18           2                        Jobst UltraSheer Thigh High
# 19           1    sizes recomended in the size chart are not real
# 20           1                                    mens ultrasheer
# 21           2                               Delicious cookie mix
# 22           1                       Another Abysmal Digital Copy
# 23           2  A fascinating insight into the life of modern ...
# 24           2     i liked this album more then i thought i would
# 25           1                 Problem with charging smaller AAAs
# 26           1                       Works, but not as advertised
# 27           1                                       Disappointed
# 28           1                                            Oh dear
# 29           2  Based on the reviews here I bought one and I'm...
# ...        ...                                                ...
# 3599970      1                                 Breaks right away.
# 3599971      1                                   No Fun With Lady
# 3599972      2                     IF MY "SWEET " WIFE CATCHED ME
# 3599973      2                                    Delicious Meal!
# 3599974      2                  Neuva Cocina Rice Mix for Chicken
# 3599975      2                                        Great meal!
# 3599976      2                                     Very enjoyable
# 3599977      1     An interesting look into Boston's comedy clubs
# 3599978      1                                        Not standup
# 3599979      2                                      A SWEET SCENT
# 3599980      2  This book now available in paper and ebook for...
# 3599981      2                                       Energie pure
# 3599982      2                                   Biology Workbook
# 3599983      1                                Cute, but very thin
# 3599984      2                                         Great book
# 3599985      2                 Useful for everything boat related
# 3599986      2                              Refreshing new artist
# 3599987      1                                    Not the Best...
# 3599988      2                                      We Love Tyler
# 3599989      2                                         Amazing CD
# 3599990      2             Buy this CD and you'll thank yourself!
# 3599991      2                                        Tyler Rocks
# 3599992      2                                            AWESOME
# 3599993      1             What A Slap In The Face To Masami Ueda
# 3599994      1                                     Too simplistic
# 3599995      1                                      Don't do it!!
# 3599996      1                      Looks nice, low functionality
# 3599997      1                         compact, but hard to clean
# 3599998      1                                 what is it saying?
# 3599999      2              Makes My Blood Run Red-White-And-Blue
#
#                                                     Review
# 0        This sound track was beautiful! It paints the ...
# 1        I'm reading a lot of reviews saying that this ...
# 2        This soundtrack is my favorite music of all ti...
# 3        I truly like this soundtrack and I enjoy video...
# 4        If you've played the game, you know how divine...
# 5        I am quite sure any of you actually taking the...
# 6        This is a self-published book, and if you want...
# 7        I loved Whisper of the wicked saints. The stor...
# 8        I just finished reading Whisper of the Wicked ...
# 9        This was a easy to read book that made me want...
# 10       A complete waste of time. Typographical errors...
# 11       This was a great book,I just could not put it ...
# 12       I thought this book was brilliant, but yet rea...
# 13       I guess you have to be a romance novel lover f...
# 14       I feel I have to write to keep others from was...
# 15       It's glaringly obvious that all of the glowing...
# 16       When you hear folks say that they don't make '...
# 17       After I had a DVT my doctor required me to wea...
# 18       Excellent product. However, they are very diff...
# 19       sizes are much smaller than what is recomended...
# 20       This model may be ok for sedentary types, but ...
# 21       I thought it was funny that I bought this prod...
# 22       Rather than scratches and insect droppings, th...
# 23       I thoroughly enjoyed Rising Sons and Daughters...
# 24       I heard a song or two and thought same o same ...
# 25       I have had the charger for more than two years...
# 26       I bought one of these chargers..the instructio...
# 27       I read the reviews,made my purchase and was ve...
# 28       I was excited to find a book ostensibly about ...
# 29       This VCR/DVD was an early Christmas present to...
# ...                                                    ...
# 3599970  We have had bad luck with this lovely toy. I t...
# 3599971  We have four battery operated engines (Thomas,...
# 3599972  WITH THIS BOOK, SHE'D SURELY MURDER ME !BUT I'...
# 3599973  After trying this chicken and rice dish, I was...
# 3599974  The rice mix makes a tasty quick meal, however...
# 3599975  A simple to prepare meal that is delicious! Yo...
# 3599976  As a huge fan of stand-up comedy and in partic...
# 3599977  This was a good documentary on the history of ...
# 3599978  Just wanted to warn everybody that this is not...
# 3599979  Since its founding in 1982 Thymes has won legi...
# 3599980  While the Moses Probe isn't available here, ch...
# 3599981  Cet ensemble de CD/DVD est une excellente vale...
# 3599982  The workbook was in excellent condition and I ...
# 3599983  I buy many stockings and pantyhose from ILOVES...
# 3599984  This is a great book, I sadly believe I have l...
# 3599985  This book is useful for pretty much any boat r...
# 3599986  Tyler Hilton is a great new artist with a refr...
# 3599987  I bought this CD expecting it to be the same t...
# 3599988  When i got this cd i thought it would be good ...
# 3599989  Tyler Hitlon's CD is awesome! If you like John...
# 3599990  Tyler Hilton....a name you might not know now,...
# 3599991  there is only one word to describe tyler hilto...
# 3599992  Absolutely amazing so relieving of my neck pai...
# 3599993  Do NOT buy this cd. Ever. This was probably ju...
# 3599994  While Mr. Harrison makes some extremely valid ...
# 3599995  The high chair looks great when it first comes...
# 3599996  I have used this highchair for 2 kids now and ...
# 3599997  We have a small house, and really wanted two o...
# 3599998  not sure what this book is supposed to be. It ...
# 3599999  I agree that every American should read this b...
#
# [3600000 rows x 3 columns]
